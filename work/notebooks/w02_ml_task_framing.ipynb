# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
#ill choose binary classification.
#reason:  to get label in yes or no. YES for page  rank drop and NO for fine page.
# so this gives us a clean list of pages that need to be fixed

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# we are predicting declining label. it comes from defined rule and is based on observation .
# if page's trend direction is down , itll be 1 otherwise 0. this gives our model a clear answer

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
#the metric ill defend is precision
# reason: if model precits our page traffic dropped, we actually want the page to lose trafic. also because of limited budget.
# low precision means waste while high precision means our recommendations are highly accurate.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import os
import sys
import subprocess
import pandas as pd

# using repository
colab="google.colab" in sys.modules
url="https://github.com/MashaalFarrukh-max/flyrank-ml-internship"
name="flyrank-ml-internship"
if colab:
    if not os.path.isdir(name):
        subprocess.run(["git", "clone","--depth", "1",url, name],check=True)
    os.chdir(name)
else:
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

#loading dataset slice
path= "data/raw/content_refresh_anonymized.csv"
df=pd.read_csv(path)
#createing target label
df['declining_label']= (df['trend_direction'] == 'down').astype(int)
#one roww display
one_row_slice= df.head(1)[['client_id','trend_direction','declining_label']]
print(one_row_slice)
# Out:
#            client_id trend_direction  declining_label
# 0  client_f369cb89fc            down                1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
#a fix rule like' if the clicks drop by 10 percent, fix the page"(if else rule) . if people are busy for example due to a football match, the traffic of page will drop.
# ML model beats fixed rules and analyzes the difference and counts the actual traffic drop .

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
