# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
#Lane 2: Refresh / Content Opportunity Scoring
#reason:
#i chose this lane because i want a smart review system that rank pages considering refresh rather than guessing , i also want to fix old pages to get good traffic instead of starting new

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
#desicion: it is to see if old page needs to be fixed and if its worth using resources like time and money.
#action: then we should assign pages to a content writer with instruction  of what to fix.
#cost of wrong cell:wasted budgets and rewritingpages or if we miss a page , drops in google ranking and we lose traffic.
#solution: to use ML, as the model can look at rankings , views at once and tell us the difference and gives prediction.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import pandas as pd
repo_url = "https://github.com/MashaalFarrukh-max/flyrank-ml-internship"  # loading repository in colab
repo_dir = "flyrank-ml-internship"

if not os.path.isdir(repo_dir):
    print("loading reposiitory files in Colab")
    # !git clone {repo_url}
os.chdir(repo_dir)
#loading dataset
data_file_path = "data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(data_file_path)
print(" thee dataset  has been loaded \n")
#calculating numbers
total_records = len(df)
down_trend_count = len(df[df['trend_direction'] == 'down'])
down_trend_pct = (down_trend_count / total_records) * 100
print("Total rows processed:", total_records)
print("Rows  with traffic drop:", down_trend_count)
print("Percentage of declining rows:", round(down_trend_pct, 2), "%")
# Out:
# loading reposiitory files in Colab
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 98 (delta 20), reused 79 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 1.83 MiB | 9.73 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
#  thee dataset  has been loaded
#
# Total rows processed: 30000
# Rows  with traffic drop: 16262
# Percentage of declining rows: 54.21 %

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
#i can claim:  the system has a guide that tells the writer which page should be given priority and which page has less traffic .
# i cant claim:  that updating the page will bring the traffic back, also cant say that we know why page's ranking dropped.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
